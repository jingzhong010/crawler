# %%
pip install selenium
# Out:
# Collecting seleniumNote: you may need to restart the kernel to use updated packages.
#
#   Downloading selenium-4.7.2-py3-none-any.whl (6.3 MB)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\jing\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\jing\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Collecting exceptiongroup>=1.0.0rc9
#   Downloading exceptiongroup-1.0.4-py3-none-any.whl (14 kB)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: idna in c:\users\jing\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\jing\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\jing\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Requirement already satisfied: sortedcontainers in c:\users\jing\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\jing\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\jing\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\jing\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, exceptiongroup, async-generator, wsproto, trio, trio-websocket, selenium
# Successfully installed async-generator-1.10 exceptiongroup-1.0.4 h11-0.14.0 outcome-1.2.0 selenium-4.7.2 trio-0.22.0 trio-websocket-0.9.2 wsproto-1.2.0

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import re
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys

# %%
data=[]
object={}
target_url = 'https://www.indeed.com/jobs?q=data+scientist&l=Corpus+Christi%2C+TX&from=searchOnHP&vjk=f0af8bad6d472c50'

headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36","Accept-Language":"en-US,en;q=0.9","Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9","Accept-Encoding":"gzip, deflate, br","upgrade-insecure-requests":"1"}

req = requests.get(target_url, headers=headers).text

for page in range(1,20):  ###change max page number here  
    req =  requests.get("https://www.zillow.com/homes/for_sale/Brooklyn,-New-York,-NY_rb/{}_p/".format(page), headers=headers).text
    soup = BeautifulSoup(req,'html.parser')

    properties = soup.find_all("div",{"class":"StyledPropertyCardDataWrapper-c11n-8-73-8__sc-1omp4c3-0 gXNuqr property-card-data"})
    print(len(properties))

    for x in range(0,len(properties)):
      try:
        object["pricing"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 hRqIYX"}).text
      except:
        object["pricing"]=None
      try:
        object["size"]=properties[x].find("div",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 ghGYOB"}).text

      except:
        object["size"]=None
      try:
        object["address"]=properties[x].find("a",{"class":"StyledPropertyCardDataArea-c11n-8-73-8__sc-yipmu-0 lhIXlm property-card-link"}).text
      except:
        object["address"]=None
      try:
        object["link"]=properties[x].find('a', {'href': re.compile("^https://")}).get('href')
      except:
        object["link"]=None
      data.append(object)
      object={}
print(data)
    
df = pd.DataFrame(data)
df
df.to_csv('newdata.csv')
# Out:
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# 9
# [{'pricing': '$855,000', 'size': '3 bds3 ba2,352 sqft - House for sale', 'address': '1498 E 29th St, Brooklyn, NY 11229', 'link': 'https://www.zillow.com/homedetails/1498-E-29th-St-Brooklyn-NY-11229/30755867_zpid/'}, {'pricing': '$599,000', 'size': '5 bds2 ba1,248 sqft - Foreclosure', 'address': '2047 E 55th St, Brooklyn, NY 11234', 'link': 'https://www.zillow.com/homedetails/2047-E-55th-St-Brooklyn-NY-11234/30787042_zpid/'}, {'pricing': '$12,950,000', 'size': '9 bds8 ba11,389 sqft - House for sale', 'address': '1305 Albemarle Rd, Brooklyn, NY 11226', 'link': 'https://www.zillow.com/homedetails/1305-Albemarle-Rd-Brooklyn-NY-11226/30666281_zpid/'}, {'pricing': '$849,000', 'size': '3 bds1 ba1,330 sqft - House for sale', 'address': '313 88th St, Brooklyn, NY 11209', 'link': 'https://www.zillow.com/homedetails/313-88th-St-Brooklyn-NY-11209/30700031_zpid/'}, {'pricing': '$995,000', 'size': '2 bds2 ba930 sqft - Condo for sale', 'address': '282 Nassau Ave APT 3A, Brooklyn, NY 11222', 'link': 'https://www.zillow.com/homedetails/282-Nassau-Ave-APT-3A-Brooklyn-NY-11222/320252911_zpid/'}, {'pricing': '$599,000', 'size': '3 bds2 ba1,000 sqft - House for sale', 'address': '5310 Avenue L, Brooklyn, NY 11234', 'link': 'https://www.zillow.com/homedetails/5310-Avenue-L-Brooklyn-NY-11234/30763267_zpid/'}, {